# %% [markdown]
# ### Author(s): evankoh
#
#
# ### Description
# This notebook aim to list all the StocksCafe APIs currently supported by StocksCafe Playground

# %% [markdown]
# ### Imports

# %%
import os
os.chdir('../')
from stockscafe.StocksCafeApi import StocksCafeApi

# %% [markdown]
# ### Create StocksCafe object

# %%
sc = StocksCafeApi()

# %% [markdown]
# ### Get Recent Prices (Includes high, low, open, close etc)

# %%
exchange = 'SGX'
symbol = 'D05'
sc.getPrices(exchange, symbol, 10)
# Out:
#    change change_percent  close currency         date   high    low   open  \
# 0   0.240          0.97%  25.08      SGD   1 Mar 2019  25.22  24.93  24.97
# 1  -0.310         -1.23%  24.84      SGD  28 Feb 2019  25.25  24.84  25.25
# 2  -0.020         -0.08%  25.15      SGD  27 Feb 2019  25.40  25.02  25.05
# 3  -0.010         -0.04%  25.17      SGD  26 Feb 2019  25.26  24.98  25.26
# 4   0.170          0.68%  25.18      SGD  25 Feb 2019  25.25  24.94  25.00
# 5   0.200          0.81%  25.01      SGD  22 Feb 2019  25.07  24.70  24.70
# 6  -0.270         -1.08%  24.81      SGD  21 Feb 2019  25.00  24.70  24.81
# 7  -0.020         -0.08%  25.08      SGD  20 Feb 2019  25.30  25.05  25.23
# 8  -0.100         -0.40%  25.10      SGD  19 Feb 2019  25.33  25.10  25.22
# 9   0.410          1.65%  25.20      SGD  18 Feb 2019  25.29  24.89  25.00
#
#       volume
# 0  2,153,700
# 1  5,343,600
# 2  3,894,500
# 3  3,196,800
# 4  3,049,000
# 5  4,219,570
# 6  5,993,300
# 7  3,509,000
# 8  3,293,078
# 9  5,147,100

# %% [markdown]
# ### How many API calls you have made today (Daily Limit = 100, Reset at 12am SGT)

# %%
sc.getUsageCount()
# Out:
#    count  latency_ms      result  result_boolean   timestamp
# 0      8           2  Successful            True  1551573489

# %% [markdown]
# ### Collected Dividends

# %%
startDate = '2018-01-01' # Format: YYYY-MM-DD
endDate = '2018-12-31'
sc.getCollectedDividends(startDate, endDate)
# Out:
#    base_curr  base_curr_div_amt  base_curr_div_amt_after_tax currency  \
# 0        SGD           0.178464                     0.178464      USD
# 1        SGD           0.219744                     0.219744      USD
# 2        SGD           0.178704                     0.178704      USD
# 3        SGD           0.004125                     0.004125      SGD
# 4        SGD           0.014133                     0.014133      SGD
# 5        SGD           0.005122                     0.005122      SGD
# 6        SGD           0.022700                     0.022700      SGD
# 7        SGD           0.012585                     0.012585      SGD
# 8        SGD           0.005685                     0.005685      SGD
# 9        SGD           0.005730                     0.005730      SGD
# 10       SGD           0.179621                     0.179621      USD
# 11       SGD           0.177514                     0.177514      USD
# 12       SGD           0.030999                     0.030999      HKD
# 13       SGD           0.020867                     0.020867      HKD
# 14       SGD           0.204652                     0.204652      USD
# 15       SGD           0.177092                     0.177092      USD
# 16       SGD           0.035000                     0.035000      SGD
# 17       SGD           0.025000                     0.025000      SGD
# 18       SGD           0.022300                     0.022300      SGD
# 19       SGD           0.008723                     0.008723      SGD
# 20       SGD           0.003510                     0.003510      SGD
# 21       SGD           0.011767                     0.011767      SGD
# 22       SGD           0.177278                     0.177278      USD
# 23       SGD           0.177142                     0.177142      USD
# 24       SGD           0.024179                     0.024179      HKD
# 25       SGD           0.174278                     0.174278      USD
# 26       SGD           0.201840                     0.201840      USD
# 27       SGD           0.037582                     0.037582      CNY
# 28       SGD           0.011398                     0.011398      SGD
# 29       SGD           0.005562                     0.005562      SGD
# 30       SGD           0.007273                     0.007273      SGD
# 31       SGD           0.022700                     0.022700      SGD
# 32       SGD           0.004090                     0.004090      SGD
# 33       SGD           0.004318                     0.004318      SGD
# 34       SGD           0.007592                     0.007592      SGD
# 35       SGD           0.172822                     0.172822      USD
# 36       SGD           0.170469                     0.170469      USD
# 37       SGD           0.198345                     0.198345      USD
# 38       SGD           0.049000                     0.049000      SGD
# 39       SGD           0.004000                     0.004000      SGD
# 40       SGD           0.023000                     0.023000      SGD
# 41       SGD           0.008000                     0.008000      SGD
# 42       SGD           0.015983                     0.015983      SGD
# 43       SGD           0.003831                     0.003831      SGD
# 44       SGD           0.004186                     0.004186      SGD
#
#      div_amt  div_amt_after_tax      ex_date exchange     pay_date  shares  \
# 0   0.130000           0.130000  24 Dec 2018      USX  31 Dec 2018     562
# 1   0.160000           0.160000  29 Nov 2018      USX  21 Dec 2018      56
# 2   0.130000           0.130000  27 Nov 2018      USX  30 Nov 2018     562
# 3   0.004125           0.004125   1 Nov 2018      SGX  28 Dec 2018    2000
# 4   0.014133           0.014133   1 Nov 2018      SGX  28 Dec 2018    2000
# 5   0.005122           0.005122   1 Nov 2018      SGX  28 Dec 2018    2000
# 6   0.022700           0.022700  30 Oct 2018      SGX  29 Nov 2018    1500
# 7   0.012585           0.012585  26 Oct 2018      SGX  29 Nov 2018    1000
# 8   0.005685           0.005685  26 Oct 2018      SGX  29 Nov 2018    1000
# 9   0.005730           0.005730  26 Oct 2018      SGX  29 Nov 2018    1000
# 10  0.130000           0.130000  26 Oct 2018      USX  31 Oct 2018     562
# 11  0.130000           0.130000  25 Sep 2018      USX  28 Sep 2018     562
# 12  0.177000           0.177000   7 Sep 2018     HKEX  28 Sep 2018    2000
# 13  0.120000           0.120000  30 Aug 2018     HKEX  12 Sep 2018    7000
# 14  0.150000           0.150000  29 Aug 2018      USX  21 Sep 2018      56
# 15  0.130000           0.130000  28 Aug 2018      USX  31 Aug 2018     562
# 16  0.035000           0.035000   2 Aug 2018      SGX  21 Aug 2018     800
# 17  0.025000           0.025000   2 Aug 2018      SGX  21 Aug 2018     800
# 18  0.022300           0.022300   1 Aug 2018      SGX  31 Aug 2018    1500
# 19  0.008723           0.008723  31 Jul 2018      SGX  29 Aug 2018    1000
# 20  0.003510           0.003510  31 Jul 2018      SGX  29 Aug 2018    1000
# 21  0.011767           0.011767  31 Jul 2018      SGX  29 Aug 2018    1000
# 22  0.130000           0.130000  26 Jul 2018      USX  31 Jul 2018     562
# 23  0.130000           0.130000  26 Jun 2018      USX  29 Jun 2018     562
# 24  0.140000           0.140000  19 Jun 2018     HKEX  28 Jun 2018    7000
# 25  0.130000           0.130000  25 May 2018      USX  31 May 2018     562
# 26  0.150000           0.150000  23 May 2018      USX  15 Jun 2018      56
# 27  0.178300           0.178300  17 May 2018     HKEX  14 Jun 2018    6000
# 28  0.011398           0.011398   3 May 2018      SGX  29 Jun 2018    2000
# 29  0.005562           0.005562   3 May 2018      SGX  29 Jun 2018    2000
# 30  0.007273           0.007273   3 May 2018      SGX  29 Jun 2018    2000
# 31  0.022700           0.022700  30 Apr 2018      SGX  31 May 2018    1500
# 32  0.004090           0.004090  26 Apr 2018      SGX  30 May 2018    1000
# 33  0.004318           0.004318  26 Apr 2018      SGX  30 May 2018    1000
# 34  0.007592           0.007592  26 Apr 2018      SGX  30 May 2018    1000
# 35  0.130000           0.130000  25 Apr 2018      USX  30 Apr 2018     562
# 36  0.130000           0.130000  26 Mar 2018      USX  29 Mar 2018     562
# 37  0.150000           0.150000  22 Feb 2018      USX  16 Mar 2018      56
# 38  0.049000           0.049000   1 Feb 2018      SGX  20 Feb 2018     800
# 39  0.004000           0.004000   1 Feb 2018      SGX  20 Feb 2018     800
# 40  0.023000           0.023000  30 Jan 2018      SGX  28 Feb 2018    1500
# 41  0.008000           0.008000  29 Jan 2018      SGX  12 Mar 2018    1000
# 42  0.015983           0.015983  29 Jan 2018      SGX   1 Mar 2018    1000
# 43  0.003831           0.003831  29 Jan 2018      SGX   1 Mar 2018    1000
# 44  0.004186           0.004186  29 Jan 2018      SGX   1 Mar 2018    1000
#
#    symbol
# 0     YYY
# 1    NVDA
# 2     YYY
# 3     ACV
# 4     ACV
# 5     ACV
# 6    N2IU
# 7    ND8U
# 8    ND8U
# 9    ND8U
# 10    YYY
# 11    YYY
# 12    799
# 13     86
# 14   NVDA
# 15    YYY
# 16    ES3
# 17    ES3
# 18   N2IU
# 19   ND8U
# 20   ND8U
# 21   ND8U
# 22    YYY
# 23    YYY
# 24     86
# 25    YYY
# 26   NVDA
# 27   1288
# 28    ACV
# 29    ACV
# 30    ACV
# 31   N2IU
# 32   ND8U
# 33   ND8U
# 34   ND8U
# 35    YYY
# 36    YYY
# 37   NVDA
# 38    ES3
# 39    ES3
# 40   N2IU
# 41   ND8U
# 42   ND8U
# 43   ND8U
# 44   ND8U
